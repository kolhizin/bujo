# %%
import test_config as cfg
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import os, os.path
import pickle
import io

import skimage
import skimage.io, skimage.transform

import sys
sys.path.append(r'../src/')

# %%
import importlib
import transform
importlib.reload(transform)

# %%
src_fname = os.path.join(cfg.sample_path, os.listdir(cfg.sample_path)[6])
print(src_fname)
src = skimage.io.imread(src_fname, as_grey=True)
# Out:
# D:/Data/bujo_sample\20190309_125151.jpg

# %%
src2 = skimage.transform.rescale(src, scale=0.05)
# Out:
# C:\Anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
plt.imshow(src2, cmap='gray')

# %%
transform.get_text_angle(src2)
# Out:
# C:\Anaconda3\lib\site-packages\skimage\transform\radon_transform.py:69: UserWarning: Radon transform: image must be zero outside the reconstruction circle
#   warn('Radon transform: image must be zero outside the '
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-363eaf187d08> in <module>()
# ----> 1 transform.get_text_angle(src2)
#
# d:\Programming\bujo_poc\src\transform.py in get_text_angle(image, min_local_maxima_dst, interval_points)
#      47     res = []
#      48     while src_tmp is not None:
# ---> 49         src_tmp, inds = process_local_maxima(src_tmp, max(image.shape)/180.0*min_local_maxima_dst)
#      50         if src_tmp is not None:
#      51             res.append(inds)
#
# d:\Programming\bujo_poc\src\transform.py in process_local_maxima(src, width)
#      26
#      27         res = src
# ---> 28         res[max(0, ind - width):min(ind+width, len(src))] = 0
#      29         return (res, inds)
#      30
#
# TypeError: slice indices must be integers or None or have an __index__ method
