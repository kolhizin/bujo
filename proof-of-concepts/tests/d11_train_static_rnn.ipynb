# %%
import test_config as cfg
import numpy as np
import itertools, functools

# %matplotlib inline
import matplotlib.pyplot as plt
import sys, os, os.path, time, datetime
import pickle, io, json

import skimage, skimage.io, skimage.transform, skimage.filters
import sklearn, sklearn.metrics

import importlib
sys.path.append('../src/')
import modutils
import word_processing as wp
import htr_model as hm
import tqdm
import tensorflow as tf
import editdistance

# %%
class BaseTransformer:
    def __init__(self):
        pass
    def transform(self, x):
        return x

    
class SequentialTransformer:
    def __init__(self, *args):
        self.stages_ = args
        
    def transform(self, x):
        res = x
        for s in self.stages_:
            res = s.transform(res)
        return res
    
class LoadImageTransformer(BaseTransformer):
    def __init__(self, path):
        self.path_ = path
        
    def transform(self, x):
        if type(x) != str:
            raise Exception("LoadImageTransformer: expects filename as argument!")
        return skimage.io.imread(os.path.join(self.path_, x), as_grey=True)
    
class ConvertFloatTransformer(BaseTransformer):
    def __init__(self, min_value = 0.0, max_value = 1.0):
        self.min_ = min_value
        self.max_ = max_value
        
    def transform(self, x):
        if x.dtype in (np.float, np.float64, np.float32):
            return x
        if x.dtype == np.uint8:
            return (x / 255.0) * (self.max_ - self.min_) + self.min_
        if x.dtype == np.uint16:
            return (x / 65535.0) * (self.max_ - self.min_) + self.min_
        raise Exception("ConvertFloatTransformer: unexpected argument type!")
    
class RandomStretchTransformer(BaseTransformer):
    def __init__(self, min_scale = 0.66, max_scale = 1.5, fill_value=1.0):
        self.max_ = max_scale
        self.min_ = min_scale
        self.fill_ = fill_value
        
    def transform(self, x):
        f = np.random.uniform(self.min_, self.max_)
        return skimage.transform.rescale(x, (1.0, f), mode='constant', cval=self.fill_)
    
class TransposeTransformer(BaseTransformer):
    def __init__(self):
        pass
    def transform(self, x):
        return np.transpose(x)
    
class FitSizeTransformer(BaseTransformer):
    def __init__(self, width, height, fill_value=1.0):
        self.w_ = width
        self.h_ = height
        self.fill_ = fill_value
        self.template_ = np.ones((self.h_, self.w_)) * self.fill_
        
    def transform(self, x):
        (h, w) = x.shape
        f = max(w / self.w_, h / self.h_)
        res = self.template_.copy()
        rw = max(min(self.w_, int(w / f)), 1)
        rh = max(min(self.h_, int(h / f)), 1)
        res[0:rh, 0:rw] = skimage.transform.resize(x, (rh, rw), mode='constant', cval=self.fill_)
        return res
    
class StandardizeTransformer(BaseTransformer):
    def __init__(self):
        pass
    
    def transform(self, x):
        m = np.mean(x)
        s = np.std(x)
        if s <= 1e-9:
            return x - m
        return (x - m) / s
    
class TruncateLabelTransform(BaseTransformer):
    def __init__(self, max_cost):
        self.max_cost_ = max_cost
        
    def transform(self, x):
        if type(x) != str:
            raise Exception("TruncateLabelTransform: input expected to be of type string!")
        cost = 0
        for i in range(len(x)):
            flg = (i > 0) and (x[i] == x[i-1])
            cost += 1 + int(flg)
            if cost > max_cost:
                return x[:i]
        return x

# %%
def format_timedelta(seconds):
    if seconds < 1e-10:
        return '0s'
    sf = seconds - np.floor(seconds)
    si = int(np.floor(seconds))
    d, s_h = divmod(si, 3600*24)
    h, s_m = divmod(s_h, 3600)
    m, s = divmod(s_m, 60)
    if d > 9:
        return '{}d'.format(d)
    elif d > 0:
        return '{}d {}h'.format(d, h)
    elif h > 9:
        return '{}h'.format(h)
    elif h > 0:
        return '{}h {}m'.format(h, m)
    elif m > 9:
        return '{}m'.format(m)
    elif m > 0:
        return '{}m {}s'.format(m, s)
    elif s > 9:
        return '{}s'.format(s)
    elif s > 0:
        return '{:.1f}s'.format(s + sf)
    else:
        return '{}ms'.format(int(sf*1000))
    
def apply_esmooth(array, factor):
    tmp = np.exp(np.cumsum([factor]*len(array)))
    tmp = tmp / np.sum(tmp)
    return np.sum(tmp * array)
    
def train(model, imgs, labels, batch_size, transform_pipeline=BaseTransformer()):
    num = len(imgs)
    num_batches = num // batch_size
    if len(imgs) > num_batches * batch_size:
        num_batches += 1
    ids = np.arange(num)
    np.random.shuffle(ids)
    text_template = 'Train batch {}/{}. Loss: {:.2f}. Time: {}. ETA: {}.'
    hist_times = []
    t_start = time.perf_counter()
    sum_loss = 0
    for i in range(num_batches):
        t0 = time.perf_counter()
        batch_ids = ids[(i*batch_size):((i+1)*batch_size)]
        batch_imgs = np.array([transform_pipeline.transform(imgs[j]) for j in batch_ids])
        batch_lbls = np.array([labels[j] for j in batch_ids])
        loss = model.trainBatch(batch_imgs, batch_lbls)
        sum_loss += loss * len(batch_lbls)
        t1 = time.perf_counter()
        hist_times.append(t1-t0)
        t_delta = apply_esmooth(np.array(hist_times)[::-1], -0.5)
        t_eta = t_delta * (num_batches - i - 1)
        print(text_template.format(i+1, num_batches, loss, format_timedelta(t1-t0), format_timedelta(t_eta)))
    return sum_loss / len(labels)
        
def validate(model, imgs, labels, batch_size,
             transform_pipeline=BaseTransformer()):
    n_char_err = 0
    n_char = 0
    n_word_ok = 0
    n_word = 0
    num_batches = len(imgs) // batch_size
    if len(imgs) > num_batches * batch_size:
        num_batches += 1
    text_template = 'Validation batch {}/{}. Time: {}. ETA: {}.'
    hist_times = []
    t_start = time.perf_counter()
    sum_loss = 0
    for i in range(num_batches):
        t0 = time.perf_counter()
        batch_imgs = np.array([transform_pipeline.transform(x)
                               for x in imgs[(i*batch_size):((i+1)*batch_size)]])
        batch_lbls = np.array(labels[(i*batch_size):((i+1)*batch_size)])
        recognized, loss = model.validBatch(batch_imgs, batch_lbls)
        sum_loss += loss * len(batch_lbls)
        for j in range(len(recognized)):
            n_word_ok += int(batch_lbls[j] == recognized[j])
            n_word += 1
            dist = editdistance.eval(recognized[j], batch_lbls[j])
            n_char_err += dist
            n_char += len(batch_lbls[j])
        t1 = time.perf_counter()
        hist_times.append(t1-t0)
        t_delta = apply_esmooth(np.array(hist_times)[::-1], -0.5)
        t_eta = t_delta * (num_batches - i - 1)
        t_eta = (t1 - t_start) / (i + 1) * (num_batches - i - 1)
        print(text_template.format(i+1, num_batches, format_timedelta(t1-t0), format_timedelta(t_eta)))

    cer = n_char_err / n_char
    wa = n_word_ok / n_word
    print('Validation results: CER: {:.3f}, WA: {:.3f}.'.format(cer, wa))
    return sum_loss/len(labels), cer, wa


def run_training(model, train_imgs, train_labels, valid_imgs, valid_labels,
                 batch_size=128, train_pipeline=BaseTransformer(), valid_pipeline=None):
    epoch = 0
    if valid_pipeline is None:
        valid_pipeline = train_pipeline
    text_template = 'Epoch {} complete in {}. T-loss is {:.2f}, V-loss is {:.2f}'
    while True:
        t0 = time.perf_counter()
        epoch += 1
        print('Epoch: {}'.format(epoch))

        tloss = train(model, train_imgs, train_labels, batch_size, transform_pipeline=train_pipeline)
        vloss, cer, wa = validate(model, valid_imgs, valid_labels, batch_size, transform_pipeline=valid_pipeline)
        model.save()
        t1 = time.perf_counter()
        print(text_template.format(epoch, format_timedelta(t1-t0), tloss, vloss))
        
def load_sample(fname):
    path = '.'.join(fname.split('.')[:-1])
    sample = [tuple(y.strip() for y in x.split(' ')) for x in open(fname, 'r').readlines()]
    load_pipeline = SequentialTransformer(LoadImageTransformer(path), ConvertFloatTransformer())
    return [x for x in sample if len(x[1])>0], load_pipeline

        
def prepare_sample(sample, pipeline):
    imgs = [pipeline.transform('{}.png'.format(x)) for (x,_) in sample]
    lbls = [x for (_,x) in sample]
    return imgs, lbls

# %%
# %%time
train_sample, train_load_pipeline = load_sample('D:/Data/HTR/train.txt')
train_imgs, train_lbls = prepare_sample(train_sample, train_load_pipeline)
# Out:
# C:\Anaconda3\lib\site-packages\skimage\io\_io.py:49: UserWarning: `as_grey` has been deprecated in favor of `as_gray`
#   warn('`as_grey` has been deprecated in favor of `as_gray`')
# Wall time: 22.7 s

# %%
# %%time
valid_sample, valid_load_pipeline = load_sample('D:/Data/HTR/valid.txt')
valid_imgs, valid_lbls = prepare_sample(valid_sample, valid_load_pipeline)
# Out:
# Wall time: 3.43 s

# %%
train_pipeline = SequentialTransformer(
    RandomStretchTransformer(),
    FitSizeTransformer(128, 32),
    TransposeTransformer(),
    StandardizeTransformer())

valid_pipeline = SequentialTransformer(
    FitSizeTransformer(128, 32),
    TransposeTransformer(),
    StandardizeTransformer())

charlist = sorted(list(functools.reduce(set.union, [set(x) for x in train_lbls])))

# %%
importlib.reload(hm)
# Out:
# <module 'htr_model' from '../src\\htr_model.py'>

# %%
# %%time
model = hm.HTRModel(charlist, img_size=(128, 32),
                cnn_kernels = [5, 5, 3, 3], #[5, 5, 3, 3, 3],#default
                cnn_features = [1, 32, 64, 64, 128], #[1, 32, 64, 128, 128, 256],#default
                cnn_pools = [(2,2), (2,2), (1,2), (1,4)], #[(2,2), (2,2), (1,2), (1,2), (1,2)] #default
                rnn_cells = [128, 128], #default 
                model_path='D:/models/htr-static-128/', decoder='best-path'
                )
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0722 21:22:06.779354 13824 deprecation_wrapper.py:119] From ../src\htr_model.py:76: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# W0722 21:22:06.799336 13824 deprecation_wrapper.py:119] From ../src\htr_model.py:82: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0722 21:22:07.770168 13824 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W0722 21:22:07.770168 13824 deprecation.py:323] From ../src\htr_model.py:107: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# W0722 21:22:07.770168 13824 deprecation.py:323] From ../src\htr_model.py:108: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# W0722 21:22:07.830090 13824 deprecation.py:506] From C:\Anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0722 21:22:07.838078 13824 deprecation.py:506] From C:\Anaconda3\lib\site-packages\tensorflow\python\ops\rnn_cell_impl.py:961: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0722 21:22:09.567767 13824 deprecation_wrapper.py:119] From ../src\htr_model.py:124: The name tf.nn.ctc_loss is deprecated. Please use tf.compat.v1.nn.ctc_loss instead.
#
# W0722 21:22:09.575785 13824 deprecation_wrapper.py:119] From ../src\htr_model.py:58: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# W0722 21:22:09.575785 13824 deprecation_wrapper.py:119] From ../src\htr_model.py:58: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# W0722 21:22:09.579746 13824 deprecation_wrapper.py:119] From ../src\htr_model.py:60: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# W0722 21:22:13.354733 13824 deprecation.py:506] From C:\Anaconda3\lib\site-packages\tensorflow\python\training\rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Python: 3.7.3 (default, Mar 27 2019, 17:13:21) [MSC v.1915 64 bit (AMD64)]; TF: 1.14.0
# Starting cold
# W0722 21:22:13.514518 13824 deprecation_wrapper.py:119] From ../src\htr_model.py:145: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
# Wall time: 7.01 s

# %%
run_training(model, train_imgs, train_lbls, valid_imgs, valid_lbls,
            batch_size=256, train_pipeline=train_pipeline, valid_pipeline=valid_pipeline)
# Out:
# Epoch: 1
# C:\Anaconda3\lib\site-packages\skimage\transform\_warps.py:24: UserWarning: The default multichannel argument (None) is deprecated.  Please specify either True or False explicitly.  multichannel will default to False starting with release 0.16.
#   warn('The default multichannel argument (None) is deprecated.  Please '
# C:\Anaconda3\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# Train batch 1/54. Loss: 126.99. Time: 5.0s. ETA: 4m 24s.
# Train batch 2/54. Loss: 69.25. Time: 2.5s. ETA: 2m 58s.
# Train batch 3/54. Loss: 25.63. Time: 2.4s. ETA: 2m 29s.
# Train batch 4/54. Loss: 23.14. Time: 2.4s. ETA: 2m 14s.
# Train batch 5/54. Loss: 23.98. Time: 2.4s. ETA: 2m 5s.
# Train batch 6/54. Loss: 23.53. Time: 2.6s. ETA: 2m 3s.
# Train batch 7/54. Loss: 22.58. Time: 2.6s. ETA: 2m 0s.
# Train batch 8/54. Loss: 22.66. Time: 3.4s. ETA: 2m 12s.
# Train batch 9/54. Loss: 21.84. Time: 4.7s. ETA: 2m 42s.
# Train batch 10/54. Loss: 22.44. Time: 2.8s. ETA: 2m 23s.
# Train batch 11/54. Loss: 21.57. Time: 2.4s. ETA: 2m 6s.
# Train batch 12/54. Loss: 21.28. Time: 2.5s. ETA: 1m 57s.
# Train batch 13/54. Loss: 19.55. Time: 2.5s. ETA: 1m 49s.
# Train batch 14/54. Loss: 20.29. Time: 2.4s. ETA: 1m 42s.
# Train batch 15/54. Loss: 20.93. Time: 2.3s. ETA: 1m 35s.
# Train batch 16/54. Loss: 20.19. Time: 2.7s. ETA: 1m 37s.
# Train batch 17/54. Loss: 19.11. Time: 3.3s. ETA: 1m 45s.
# Train batch 18/54. Loss: 20.11. Time: 2.4s. ETA: 1m 36s.
# Train batch 19/54. Loss: 19.12. Time: 2.4s. ETA: 1m 30s.
# Train batch 20/54. Loss: 20.55. Time: 2.4s. ETA: 1m 26s.
# Train batch 21/54. Loss: 19.70. Time: 2.6s. ETA: 1m 23s.
# Train batch 22/54. Loss: 19.43. Time: 2.6s. ETA: 1m 21s.
# Train batch 23/54. Loss: 20.19. Time: 2.7s. ETA: 1m 20s.
# Train batch 24/54. Loss: 19.60. Time: 2.6s. ETA: 1m 18s.
# Train batch 25/54. Loss: 18.53. Time: 2.4s. ETA: 1m 13s.
# Train batch 26/54. Loss: 20.62. Time: 2.4s. ETA: 1m 9s.
# Train batch 27/54. Loss: 20.33. Time: 2.5s. ETA: 1m 7s.
# Train batch 28/54. Loss: 20.34. Time: 2.4s. ETA: 1m 3s.
# Train batch 29/54. Loss: 19.80. Time: 2.3s. ETA: 59s.
# Train batch 30/54. Loss: 20.22. Time: 2.4s. ETA: 56s.
# Train batch 31/54. Loss: 20.03. Time: 2.4s. ETA: 54s.
# Train batch 32/54. Loss: 18.92. Time: 3.1s. ETA: 58s.
# Validation batch 27/36. Time: 795ms. ETA: 7.0s.
# Validation batch 28/36. Time: 743ms. ETA: 6.3s.
# Validation batch 29/36. Time: 748ms. ETA: 5.5s.
# Validation batch 30/36. Time: 742ms. ETA: 4.7s.
# Validation batch 31/36. Time: 762ms. ETA: 3.9s.
# Validation batch 32/36. Time: 734ms. ETA: 3.1s.
# Validation batch 33/36. Time: 797ms. ETA: 2.3s.
# Validation batch 34/36. Time: 745ms. ETA: 1.6s.
# Validation batch 35/36. Time: 773ms. ETA: 777ms.
# Validation batch 36/36. Time: 729ms. ETA: 0s.
# Validation results: CER: 1.000, WA: 0.000.
# Epoch 1 complete in 2m 50s. T-loss is 22.39, V-loss is 18.00
# Epoch: 2
# Train batch 1/54. Loss: 18.71. Time: 2.5s. ETA: 2m 14s.
# Train batch 2/54. Loss: 17.54. Time: 2.5s. ETA: 2m 10s.
# Train batch 3/54. Loss: 17.16. Time: 2.4s. ETA: 2m 4s.
# Train batch 4/54. Loss: 17.71. Time: 2.3s. ETA: 1m 59s.
# Train batch 5/54. Loss: 17.43. Time: 2.5s. ETA: 1m 59s.
# Train batch 6/54. Loss: 17.21. Time: 2.4s. ETA: 1m 55s.
# Train batch 7/54. Loss: 17.74. Time: 2.3s. ETA: 1m 51s.
# Train batch 8/54. Loss: 18.09. Time: 2.4s. ETA: 1m 49s.
# Train batch 9/54. Loss: 17.87. Time: 2.5s. ETA: 1m 48s.
# Train batch 10/54. Loss: 16.62. Time: 2.6s. ETA: 1m 50s.
# Train batch 11/54. Loss: 17.84. Time: 2.3s. ETA: 1m 44s.
# Train batch 12/54. Loss: 16.58. Time: 2.4s. ETA: 1m 41s.
# Train batch 13/54. Loss: 18.09. Time: 2.5s. ETA: 1m 39s.
# Train batch 14/54. Loss: 17.42. Time: 2.6s. ETA: 1m 39s.
# Train batch 15/54. Loss: 16.52. Time: 2.6s. ETA: 1m 38s.
# Train batch 16/54. Loss: 16.58. Time: 2.6s. ETA: 1m 37s.
# Train batch 17/54. Loss: 18.43. Time: 2.6s. ETA: 1m 34s.
# Train batch 18/54. Loss: 18.27. Time: 2.7s. ETA: 1m 34s.
# Train batch 19/54. Loss: 18.43. Time: 2.6s. ETA: 1m 30s.
# Train batch 20/54. Loss: 17.47. Time: 2.5s. ETA: 1m 26s.
# Train batch 21/54. Loss: 17.41. Time: 2.5s. ETA: 1m 23s.
# Train batch 22/54. Loss: 17.36. Time: 2.5s. ETA: 1m 21s.
# Train batch 23/54. Loss: 18.45. Time: 2.8s. ETA: 1m 21s.
# Train batch 24/54. Loss: 17.91. Time: 2.5s. ETA: 1m 16s.
# Train batch 25/54. Loss: 17.68. Time: 2.6s. ETA: 1m 14s.
# Train batch 26/54. Loss: 16.97. Time: 2.7s. ETA: 1m 12s.
# Train batch 27/54. Loss: 18.28. Time: 2.4s. ETA: 1m 8s.
# Train batch 28/54. Loss: 17.05. Time: 2.3s. ETA: 1m 3s.
# Train batch 29/54. Loss: 17.86. Time: 2.4s. ETA: 1m 1s.
# Train batch 30/54. Loss: 18.02. Time: 2.5s. ETA: 58s.
# Validation batch 24/36. Time: 857ms. ETA: 9.5s.
# Validation batch 25/36. Time: 823ms. ETA: 8.7s.
# Validation batch 26/36. Time: 800ms. ETA: 8.0s.
# Validation batch 27/36. Time: 902ms. ETA: 7.2s.
# Validation batch 28/36. Time: 778ms. ETA: 6.4s.
# Validation batch 29/36. Time: 740ms. ETA: 5.6s.
# Validation batch 30/36. Time: 782ms. ETA: 4.8s.
# Validation batch 31/36. Time: 788ms. ETA: 4.0s.
# Validation batch 32/36. Time: 768ms. ETA: 3.2s.
# Validation batch 33/36. Time: 768ms. ETA: 2.4s.
# Validation batch 34/36. Time: 779ms. ETA: 1.6s.
# Validation batch 35/36. Time: 797ms. ETA: 794ms.
# Validation batch 36/36. Time: 741ms. ETA: 0s.
# Validation results: CER: 1.000, WA: 0.000.
# W0722 21:28:01.506611 13824 deprecation.py:323] From C:\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py:960: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# Epoch 2 complete in 2m 42s. T-loss is 17.24, V-loss is 17.44
# Epoch: 3
# Train batch 1/54. Loss: 17.65. Time: 2.4s. ETA: 2m 4s.
# Train batch 2/54. Loss: 18.20. Time: 2.4s. ETA: 2m 3s.
# Train batch 3/54. Loss: 15.80. Time: 3.0s. ETA: 2m 17s.
# Train batch 4/54. Loss: 17.75. Time: 2.5s. ETA: 2m 10s.
# Train batch 5/54. Loss: 17.71. Time: 2.7s. ETA: 2m 9s.
# Train batch 6/54. Loss: 18.59. Time: 2.4s. ETA: 2m 1s.
# Train batch 7/54. Loss: 18.26. Time: 2.4s. ETA: 1m 56s.
# Train batch 8/54. Loss: 16.50. Time: 2.4s. ETA: 1m 51s.
# Train batch 9/54. Loss: 16.65. Time: 2.4s. ETA: 1m 47s.
# Train batch 10/54. Loss: 16.28. Time: 2.3s. ETA: 1m 44s.
# Train batch 11/54. Loss: 18.16. Time: 2.4s. ETA: 1m 41s.
# Train batch 12/54. Loss: 16.99. Time: 2.3s. ETA: 1m 38s.
# Train batch 13/54. Loss: 17.32. Time: 2.5s. ETA: 1m 38s.
# Train batch 14/54. Loss: 18.59. Time: 2.4s. ETA: 1m 35s.
# Train batch 15/54. Loss: 16.23. Time: 2.3s. ETA: 1m 32s.
# Train batch 16/54. Loss: 16.66. Time: 2.3s. ETA: 1m 29s.
# Train batch 17/54. Loss: 16.82. Time: 2.5s. ETA: 1m 29s.
# Train batch 18/54. Loss: 16.79. Time: 2.5s. ETA: 1m 28s.
# Train batch 19/54. Loss: 17.59. Time: 2.9s. ETA: 1m 31s.
# Train batch 20/54. Loss: 17.43. Time: 2.6s. ETA: 1m 29s.
# Train batch 21/54. Loss: 15.59. Time: 2.7s. ETA: 1m 27s.
# Train batch 22/54. Loss: 17.01. Time: 2.5s. ETA: 1m 22s.
# Train batch 23/54. Loss: 16.59. Time: 2.7s. ETA: 1m 20s.
# Train batch 24/54. Loss: 16.43. Time: 2.4s. ETA: 1m 15s.
# Train batch 25/54. Loss: 16.63. Time: 2.6s. ETA: 1m 13s.
# Train batch 26/54. Loss: 16.75. Time: 2.3s. ETA: 1m 9s.
# Train batch 27/54. Loss: 16.34. Time: 2.4s. ETA: 1m 5s.
# Train batch 28/54. Loss: 15.50. Time: 2.6s. ETA: 1m 4s.
# Train batch 29/54. Loss: 18.28. Time: 7m 10s. ETA: 1h 11m.
# Train batch 30/54. Loss: 15.40. Time: 3.2s. ETA: 42m.
# Train batch 31/54. Loss: 17.13. Time: 3.5s. ETA: 24m.
# Train batch 32/54. Loss: 16.56. Time: 3.2s. ETA: 14m.
# Train batch 33/54. Loss: 16.38. Time: 2.9s. ETA: 9m 3s.
# Train batch 34/54. Loss: 17.41. Time: 2.8s. ETA: 5m 36s.
# Train batch 35/54. Loss: 16.46. Time: 3.0s. ETA: 3m 35s.
# Train batch 36/54. Loss: 17.72. Time: 2.6s. ETA: 2m 22s.
# Train batch 37/54. Loss: 15.60. Time: 2.6s. ETA: 1m 38s.
# Train batch 38/54. Loss: 16.04. Time: 2.6s. ETA: 1m 12s.
# Train batch 39/54. Loss: 16.87. Time: 2.8s. ETA: 57s.
# Train batch 40/54. Loss: 16.40. Time: 2.8s. ETA: 48s.
# Train batch 41/54. Loss: 16.91. Time: 2.8s. ETA: 41s.
# Train batch 42/54. Loss: 16.82. Time: 2.3s. ETA: 34s.
# Train batch 43/54. Loss: 17.46. Time: 2.4s. ETA: 29s.
# Train batch 44/54. Loss: 17.06. Time: 2.4s. ETA: 25s.
# Train batch 45/54. Loss: 15.87. Time: 2.6s. ETA: 23s.
# Train batch 46/54. Loss: 17.13. Time: 2.8s. ETA: 21s.
# Train batch 47/54. Loss: 15.93. Time: 2.4s. ETA: 17s.
# Train batch 48/54. Loss: 17.29. Time: 2.3s. ETA: 14s.
# Train batch 49/54. Loss: 15.56. Time: 2.3s. ETA: 11s.
# Train batch 50/54. Loss: 16.79. Time: 2.3s. ETA: 9.5s.
# Train batch 51/54. Loss: 16.26. Time: 2.3s. ETA: 7.1s.
# Train batch 52/54. Loss: 16.17. Time: 2.3s. ETA: 4.7s.
# Train batch 53/54. Loss: 14.78. Time: 2.3s. ETA: 2.3s.
# Train batch 54/54. Loss: 16.63. Time: 2.5s. ETA: 0s.
# Validation batch 1/36. Time: 859ms. ETA: 30s.
# Validation batch 2/36. Time: 891ms. ETA: 29s.
# Validation batch 3/36. Time: 834ms. ETA: 28s.
# Validation batch 4/36. Time: 826ms. ETA: 27s.
# Validation batch 5/36. Time: 793ms. ETA: 26s.
# Validation batch 6/36. Time: 786ms. ETA: 25s.
# Validation batch 7/36. Time: 750ms. ETA: 23s.
# Validation batch 8/36. Time: 725ms. ETA: 22s.
# Validation batch 9/36. Time: 720ms. ETA: 21s.
# Validation batch 10/36. Time: 742ms. ETA: 20s.
# Validation batch 11/36. Time: 737ms. ETA: 19s.
# Validation batch 12/36. Time: 731ms. ETA: 18s.
# Validation batch 13/36. Time: 740ms. ETA: 17s.
# Validation batch 14/36. Time: 743ms. ETA: 17s.
# Validation batch 15/36. Time: 724ms. ETA: 16s.
# Validation batch 16/36. Time: 727ms. ETA: 15s.
# Validation batch 17/36. Time: 731ms. ETA: 14s.
# Validation batch 18/36. Time: 744ms. ETA: 13s.
# Validation batch 16/36. Time: 838ms. ETA: 15s.
# Validation batch 17/36. Time: 757ms. ETA: 14s.
# Validation batch 18/36. Time: 739ms. ETA: 13s.
# Validation batch 19/36. Time: 751ms. ETA: 13s.
# Validation batch 20/36. Time: 737ms. ETA: 12s.
# Validation batch 21/36. Time: 752ms. ETA: 11s.
# Validation batch 22/36. Time: 738ms. ETA: 10s.
# Validation batch 23/36. Time: 798ms. ETA: 9.9s.
# Validation batch 24/36. Time: 761ms. ETA: 9.2s.
# Validation batch 25/36. Time: 723ms. ETA: 8.4s.
# Validation batch 26/36. Time: 736ms. ETA: 7.6s.
# Validation batch 27/36. Time: 795ms. ETA: 6.9s.
# Validation batch 28/36. Time: 729ms. ETA: 6.1s.
# Validation batch 29/36. Time: 737ms. ETA: 5.3s.
# Validation batch 30/36. Time: 1.2s. ETA: 4.7s.
# Validation batch 31/36. Time: 987ms. ETA: 3.9s.
# Validation batch 32/36. Time: 927ms. ETA: 3.2s.
# Validation batch 33/36. Time: 923ms. ETA: 2.4s.
# Validation batch 34/36. Time: 953ms. ETA: 1.6s.
# Validation batch 35/36. Time: 937ms. ETA: 801ms.
# Validation batch 36/36. Time: 913ms. ETA: 0s.
# Validation results: CER: 1.000, WA: 0.000.
# Epoch 4 complete in 2m 36s. T-loss is 16.04, V-loss is 15.93
# Epoch: 5
# Train batch 1/54. Loss: 15.94. Time: 2.8s. ETA: 2m 30s.
# Train batch 2/54. Loss: 16.24. Time: 2.9s. ETA: 2m 29s.
# Train batch 3/54. Loss: 16.40. Time: 2.8s. ETA: 2m 25s.
# Train batch 4/54. Loss: 14.54. Time: 2.9s. ETA: 2m 23s.
# Train batch 5/54. Loss: 16.22. Time: 3.1s. ETA: 2m 25s.
# Train batch 6/54. Loss: 16.41. Time: 56s. ETA: 20m.
# Train batch 7/54. Loss: 16.79. Time: 3.5s. ETA: 12m.
# Train batch 8/54. Loss: 15.50. Time: 2.8s. ETA: 8m 24s.
# Train batch 9/54. Loss: 16.23. Time: 2.6s. ETA: 5m 44s.
# Train batch 10/54. Loss: 16.68. Time: 2.5s. ETA: 4m 7s.
# Train batch 11/54. Loss: 16.25. Time: 2.5s. ETA: 3m 8s.
# Train batch 12/54. Loss: 15.06. Time: 3.4s. ETA: 2m 48s.
# Train batch 13/54. Loss: 15.75. Time: 3.1s. ETA: 2m 29s.
# Train batch 14/54. Loss: 15.49. Time: 2.5s. ETA: 2m 7s.
# Train batch 15/54. Loss: 15.04. Time: 2.4s. ETA: 1m 52s.
# Train batch 16/54. Loss: 16.25. Time: 2.4s. ETA: 1m 41s.
# Train batch 17/54. Loss: 15.50. Time: 2.4s. ETA: 1m 34s.
# Train batch 18/54. Loss: 15.93. Time: 2.4s. ETA: 1m 29s.
# Train batch 19/54. Loss: 16.40. Time: 2.4s. ETA: 1m 26s.
# Train batch 20/54. Loss: 14.93. Time: 2.4s. ETA: 1m 23s.
# Train batch 21/54. Loss: 15.17. Time: 2.8s. ETA: 1m 25s.
# Train batch 22/54. Loss: 15.01. Time: 2.7s. ETA: 1m 24s.
# Train batch 23/54. Loss: 15.34. Time: 2.4s. ETA: 1m 19s.
# Train batch 24/54. Loss: 15.66. Time: 2.4s. ETA: 1m 14s.
# Train batch 25/54. Loss: 15.37. Time: 2.5s. ETA: 1m 12s.
# Train batch 26/54. Loss: 16.29. Time: 2.5s. ETA: 1m 9s.
# Train batch 27/54. Loss: 15.49. Time: 2.3s. ETA: 1m 5s.
# Train batch 28/54. Loss: 14.57. Time: 2.3s. ETA: 1m 2s.
# Train batch 29/54. Loss: 15.24. Time: 2.4s. ETA: 59s.
# Train batch 30/54. Loss: 16.44. Time: 2.4s. ETA: 57s.
# Train batch 31/54. Loss: 15.28. Time: 2.5s. ETA: 55s.
# Train batch 32/54. Loss: 15.71. Time: 2.3s. ETA: 52s.
# Train batch 33/54. Loss: 14.91. Time: 2.4s. ETA: 50s.
# Train batch 34/54. Loss: 16.02. Time: 2.3s. ETA: 47s.
# Train batch 35/54. Loss: 15.70. Time: 2.3s. ETA: 44s.
# Train batch 36/54. Loss: 15.30. Time: 2.5s. ETA: 43s.
# Train batch 37/54. Loss: 14.80. Time: 2.5s. ETA: 41s.
# Train batch 38/54. Loss: 15.53. Time: 2.4s. ETA: 38s.
# Train batch 39/54. Loss: 16.37. Time: 2.4s. ETA: 36s.
# Train batch 40/54. Loss: 14.95. Time: 2.3s. ETA: 33s.
# Train batch 41/54. Loss: 16.66. Time: 2.4s. ETA: 31s.
# Train batch 42/54. Loss: 17.49. Time: 2.3s. ETA: 28s.
# Train batch 43/54. Loss: 15.97. Time: 2.3s. ETA: 25s.
# Train batch 44/54. Loss: 16.14. Time: 2.4s. ETA: 23s.
# Train batch 45/54. Loss: 14.89. Time: 2.6s. ETA: 21s.
# Train batch 46/54. Loss: 15.69. Time: 2.4s. ETA: 19s.
# Train batch 47/54. Loss: 14.67. Time: 2.6s. ETA: 17s.
# Train batch 48/54. Loss: 16.93. Time: 2.5s. ETA: 14s.
# Train batch 49/54. Loss: 15.36. Time: 2.5s. ETA: 12s.
# Train batch 50/54. Loss: 16.04. Time: 2.4s. ETA: 9.8s.
# Train batch 51/54. Loss: 16.60. Time: 2.4s. ETA: 7.3s.
# Train batch 52/54. Loss: 15.58. Time: 2.5s. ETA: 4.9s.
# Train batch 53/54. Loss: 15.08. Time: 2.4s. ETA: 2.4s.
# Train batch 54/54. Loss: 15.52. Time: 2.4s. ETA: 0s.
# Validation batch 1/36. Time: 802ms. ETA: 28s.
# Validation batch 2/36. Time: 756ms. ETA: 26s.
# Validation batch 3/36. Time: 761ms. ETA: 25s.
# Validation batch 4/36. Time: 758ms. ETA: 24s.
# Validation batch 5/36. Time: 770ms. ETA: 23s.
# Validation batch 6/36. Time: 796ms. ETA: 23s.
# Validation batch 7/36. Time: 759ms. ETA: 22s.
# Validation batch 8/36. Time: 794ms. ETA: 21s.
# Validation batch 9/36. Time: 797ms. ETA: 21s.
# Validation batch 10/36. Time: 755ms. ETA: 20s.
# Validation batch 11/36. Time: 811ms. ETA: 19s.
# Validation batch 12/36. Time: 793ms. ETA: 18s.
# Train batch 21/54. Loss: 14.96. Time: 2.5s. ETA: 1m 19s.
# Train batch 22/54. Loss: 15.40. Time: 2.4s. ETA: 1m 16s.
# Train batch 23/54. Loss: 16.12. Time: 2.4s. ETA: 1m 13s.
# Train batch 24/54. Loss: 14.65. Time: 2.4s. ETA: 1m 11s.
# Train batch 25/54. Loss: 15.76. Time: 2.6s. ETA: 1m 11s.
# Train batch 26/54. Loss: 15.46. Time: 2.6s. ETA: 1m 10s.
# Train batch 27/54. Loss: 15.70. Time: 2.5s. ETA: 1m 7s.
# Train batch 28/54. Loss: 15.31. Time: 2.9s. ETA: 1m 8s.
# Train batch 29/54. Loss: 15.87. Time: 2.7s. ETA: 1m 6s.
# Train batch 30/54. Loss: 15.00. Time: 2.4s. ETA: 1m 1s.
# Train batch 31/54. Loss: 15.88. Time: 2.7s. ETA: 59s.
# Train batch 32/54. Loss: 15.51. Time: 2.5s. ETA: 56s.
# Train batch 33/54. Loss: 17.15. Time: 2.6s. ETA: 54s.
# Train batch 34/54. Loss: 16.64. Time: 2.5s. ETA: 51s.
# Train batch 35/54. Loss: 14.48. Time: 2.5s. ETA: 48s.
# Train batch 36/54. Loss: 16.35. Time: 2.4s. ETA: 44s.
# Train batch 37/54. Loss: 15.24. Time: 2.6s. ETA: 42s.
# Train batch 38/54. Loss: 14.23. Time: 2.4s. ETA: 39s.
# Train batch 39/54. Loss: 15.23. Time: 2.4s. ETA: 36s.
# Train batch 40/54. Loss: 14.57. Time: 2.4s. ETA: 33s.
# Train batch 41/54. Loss: 14.91. Time: 2.4s. ETA: 31s.
# Train batch 42/54. Loss: 15.44. Time: 2.5s. ETA: 29s.
# Train batch 43/54. Loss: 15.58. Time: 2.4s. ETA: 26s.
# Train batch 44/54. Loss: 16.07. Time: 2.6s. ETA: 24s.
# Train batch 45/54. Loss: 14.86. Time: 2.4s. ETA: 22s.
# Train batch 46/54. Loss: 15.49. Time: 2.4s. ETA: 19s.
# Train batch 47/54. Loss: 14.80. Time: 2.4s. ETA: 17s.
# Train batch 48/54. Loss: 14.59. Time: 2.6s. ETA: 15s.
# Train batch 49/54. Loss: 13.83. Time: 3.0s. ETA: 13s.
# Train batch 50/54. Loss: 15.33. Time: 3.1s. ETA: 11s.
# Train batch 51/54. Loss: 14.95. Time: 3.3s. ETA: 9.0s.
# Train batch 52/54. Loss: 15.11. Time: 3.2s. ETA: 6.1s.
# Train batch 53/54. Loss: 14.40. Time: 3.0s. ETA: 3.0s.
# Train batch 54/54. Loss: 14.06. Time: 2.8s. ETA: 0s.
# Validation batch 1/36. Time: 961ms. ETA: 33s.
# Validation batch 2/36. Time: 769ms. ETA: 29s.
# Validation batch 3/36. Time: 784ms. ETA: 27s.
# Validation batch 4/36. Time: 820ms. ETA: 26s.
# Validation batch 5/36. Time: 950ms. ETA: 26s.
# Validation batch 6/36. Time: 826ms. ETA: 25s.
# Validation batch 7/36. Time: 933ms. ETA: 25s.
# Validation batch 8/36. Time: 781ms. ETA: 23s.
# Validation batch 9/36. Time: 762ms. ETA: 22s.
# Train batch 19/54. Loss: 15.10. Time: 2.5s. ETA: 1m 25s.
# Train batch 20/54. Loss: 15.54. Time: 2.7s. ETA: 1m 26s.
# Train batch 21/54. Loss: 15.29. Time: 2.9s. ETA: 1m 28s.
# Train batch 22/54. Loss: 15.43. Time: 2.6s. ETA: 1m 25s.
# Train batch 23/54. Loss: 15.68. Time: 2.5s. ETA: 1m 20s.
# Train batch 24/54. Loss: 14.28. Time: 2.4s. ETA: 1m 15s.
# Train batch 25/54. Loss: 15.63. Time: 2.4s. ETA: 1m 11s.
# Train batch 26/54. Loss: 15.21. Time: 2.4s. ETA: 1m 8s.
# Train batch 27/54. Loss: 14.54. Time: 2.3s. ETA: 1m 4s.
# Train batch 28/54. Loss: 14.84. Time: 2.4s. ETA: 1m 2s.
# Train batch 29/54. Loss: 16.02. Time: 2.4s. ETA: 59s.
# Train batch 30/54. Loss: 15.66. Time: 2.5s. ETA: 58s.
# Train batch 31/54. Loss: 14.98. Time: 2.7s. ETA: 58s.
# Train batch 32/54. Loss: 14.42. Time: 2.6s. ETA: 56s.
# Train batch 33/54. Loss: 13.60. Time: 2.6s. ETA: 54s.
# Train batch 34/54. Loss: 14.13. Time: 2.6s. ETA: 51s.
# Train batch 35/54. Loss: 13.49. Time: 2.6s. ETA: 49s.
# Train batch 36/54. Loss: 15.26. Time: 2.6s. ETA: 47s.
# Train batch 37/54. Loss: 15.74. Time: 2.7s. ETA: 45s.
# Train batch 38/54. Loss: 16.15. Time: 2.7s. ETA: 42s.
# Train batch 39/54. Loss: 14.79. Time: 2.6s. ETA: 39s.
# Train batch 40/54. Loss: 15.47. Time: 2.6s. ETA: 37s.
# Train batch 41/54. Loss: 13.88. Time: 2.6s. ETA: 34s.
# Train batch 42/54. Loss: 14.51. Time: 2.6s. ETA: 31s.
# Train batch 43/54. Loss: 14.07. Time: 2.6s. ETA: 28s.
# Train batch 44/54. Loss: 14.94. Time: 2.8s. ETA: 26s.
# Train batch 45/54. Loss: 14.14. Time: 2.6s. ETA: 23s.
# Train batch 46/54. Loss: 13.71. Time: 2.6s. ETA: 20s.
# Train batch 47/54. Loss: 14.34. Time: 2.6s. ETA: 18s.
# Train batch 48/54. Loss: 14.50. Time: 2.7s. ETA: 15s.
# Train batch 49/54. Loss: 13.99. Time: 3.1s. ETA: 14s.
# Train batch 50/54. Loss: 15.48. Time: 3.4s. ETA: 12s.
# Train batch 51/54. Loss: 15.12. Time: 3.0s. ETA: 9.2s.
# Train batch 52/54. Loss: 15.18. Time: 2.9s. ETA: 6.0s.
# Train batch 53/54. Loss: 16.17. Time: 2.9s. ETA: 3.0s.
# Train batch 54/54. Loss: 15.73. Time: 3.1s. ETA: 0s.
# Validation batch 1/36. Time: 995ms. ETA: 34s.
# Validation batch 2/36. Time: 921ms. ETA: 32s.
# Validation batch 3/36. Time: 964ms. ETA: 31s.
# Validation batch 4/36. Time: 1.0s. ETA: 31s.
# Validation batch 5/36. Time: 1.0s. ETA: 30s.
# Validation batch 6/36. Time: 913ms. ETA: 29s.
# Validation batch 7/36. Time: 1.0s. ETA: 28s.
# Validation batch 8/36. Time: 1.1s. ETA: 27s.
# Validation batch 9/36. Time: 915ms. ETA: 26s.
# Validation batch 10/36. Time: 974ms. ETA: 25s.
# Validation batch 11/36. Time: 1.0s. ETA: 24s.
# Validation batch 12/36. Time: 1.4s. ETA: 24s.
# Validation batch 13/36. Time: 967ms. ETA: 23s.
# Validation batch 14/36. Time: 1.1s. ETA: 22s.
# Validation batch 15/36. Time: 934ms. ETA: 21s.
# Validation batch 16/36. Time: 1.1s. ETA: 20s.
# Validation batch 17/36. Time: 1.4s. ETA: 19s.
# Validation batch 18/36. Time: 878ms. ETA: 18s.
# Validation batch 19/36. Time: 813ms. ETA: 17s.
# Validation batch 20/36. Time: 858ms. ETA: 16s.
# Validation batch 21/36. Time: 782ms. ETA: 15s.
# Validation batch 22/36. Time: 772ms. ETA: 13s.
# Validation batch 23/36. Time: 757ms. ETA: 12s.
# Validation batch 24/36. Time: 793ms. ETA: 11s.
# Validation batch 25/36. Time: 774ms. ETA: 10s.
# Validation batch 26/36. Time: 753ms. ETA: 9.6s.
# Validation batch 27/36. Time: 783ms. ETA: 8.6s.
# Validation batch 28/36. Time: 775ms. ETA: 7.6s.
# Validation batch 29/36. Time: 764ms. ETA: 6.6s.
# Validation batch 30/36. Time: 781ms. ETA: 5.6s.
# Validation batch 31/36. Time: 765ms. ETA: 4.7s.
# Validation batch 32/36. Time: 774ms. ETA: 3.7s.
# Validation batch 33/36. Time: 766ms. ETA: 2.8s.
# Validation batch 34/36. Time: 776ms. ETA: 1.8s.
# Validation batch 35/36. Time: 777ms. ETA: 914ms.
# Validation batch 36/36. Time: 773ms. ETA: 0s.
# Validation results: CER: 0.953, WA: 0.028.
# Epoch 7 complete in 2m 53s. T-loss is 14.85, V-loss is 15.07
# Epoch: 8
# Train batch 1/54. Loss: 14.06. Time: 2.4s. ETA: 2m 6s.
# Train batch 2/54. Loss: 14.95. Time: 2.4s. ETA: 2m 3s.
# Train batch 3/54. Loss: 14.71. Time: 2.4s. ETA: 2m 0s.
# Train batch 4/54. Loss: 13.80. Time: 2.4s. ETA: 1m 59s.
# Train batch 5/54. Loss: 14.59. Time: 2.5s. ETA: 1m 59s.
# Train batch 6/54. Loss: 14.43. Time: 2.4s. ETA: 1m 55s.
# Train batch 7/54. Loss: 16.00. Time: 2.4s. ETA: 1m 52s.
# Train batch 8/54. Loss: 14.78. Time: 2.4s. ETA: 1m 50s.
# Train batch 9/54. Loss: 14.44. Time: 2.6s. ETA: 1m 50s.
# Train batch 10/54. Loss: 14.16. Time: 2.4s. ETA: 1m 46s.
# Train batch 11/54. Loss: 15.75. Time: 2.5s. ETA: 1m 45s.
# Train batch 12/54. Loss: 15.61. Time: 2.6s. ETA: 1m 44s.
# Train batch 13/54. Loss: 14.94. Time: 2.5s. ETA: 1m 42s.
# Train batch 14/54. Loss: 13.76. Time: 2.8s. ETA: 1m 44s.
# Train batch 15/54. Loss: 14.31. Time: 2.9s. ETA: 1m 46s.
# Train batch 16/54. Loss: 14.65. Time: 2.7s. ETA: 1m 43s.
# Train batch 17/54. Loss: 13.59. Time: 2.6s. ETA: 1m 38s.
# Train batch 18/54. Loss: 14.08. Time: 2.5s. ETA: 1m 34s.
# Train batch 19/54. Loss: 14.06. Time: 2.6s. ETA: 1m 31s.
# Train batch 20/54. Loss: 13.92. Time: 2.8s. ETA: 1m 31s.
# Train batch 21/54. Loss: 13.90. Time: 3.2s. ETA: 1m 35s.
# Train batch 22/54. Loss: 14.32. Time: 2.7s. ETA: 1m 29s.
# Train batch 23/54. Loss: 14.15. Time: 3.0s. ETA: 1m 29s.
# Train batch 24/54. Loss: 14.92. Time: 3.0s. ETA: 1m 28s.
# Train batch 25/54. Loss: 13.77. Time: 2.9s. ETA: 1m 25s.
# Train batch 26/54. Loss: 15.52. Time: 3.0s. ETA: 1m 22s.
# Train batch 27/54. Loss: 14.34. Time: 3.5s. ETA: 1m 25s.
# Train batch 28/54. Loss: 14.54. Time: 3.7s. ETA: 1m 27s.
# Train batch 29/54. Loss: 15.28. Time: 3.4s. ETA: 1m 24s.
# Train batch 30/54. Loss: 13.61. Time: 3.1s. ETA: 1m 18s.
# Train batch 31/54. Loss: 13.85. Time: 3.0s. ETA: 1m 12s.
# Train batch 32/54. Loss: 16.13. Time: 3.1s. ETA: 1m 8s.
# Train batch 33/54. Loss: 13.85. Time: 3.1s. ETA: 1m 5s.
# Train batch 34/54. Loss: 15.11. Time: 3.0s. ETA: 1m 1s.
# Train batch 35/54. Loss: 15.14. Time: 3.0s. ETA: 57s.
# Train batch 36/54. Loss: 14.38. Time: 2.7s. ETA: 52s.
# Train batch 37/54. Loss: 14.23. Time: 2.8s. ETA: 48s.
# Train batch 38/54. Loss: 14.51. Time: 3.0s. ETA: 47s.
# Train batch 39/54. Loss: 13.80. Time: 3.5s. ETA: 47s.
# Train batch 40/54. Loss: 15.52. Time: 3.1s. ETA: 44s.
# Train batch 41/54. Loss: 14.44. Time: 2.7s. ETA: 38s.
# Train batch 42/54. Loss: 14.29. Time: 2.6s. ETA: 34s.
# Train batch 43/54. Loss: 14.83. Time: 2.5s. ETA: 29s.
# Train batch 44/54. Loss: 14.64. Time: 2.6s. ETA: 26s.
# Train batch 45/54. Loss: 14.23. Time: 2.4s. ETA: 23s.
# Train batch 46/54. Loss: 13.71. Time: 2.4s. ETA: 20s.
# Train batch 47/54. Loss: 13.93. Time: 2.3s. ETA: 17s.
# Train batch 48/54. Loss: 14.58. Time: 2.4s. ETA: 14s.
# Train batch 49/54. Loss: 14.38. Time: 2.4s. ETA: 12s.
# Train batch 50/54. Loss: 14.50. Time: 2.5s. ETA: 9.8s.
# Train batch 51/54. Loss: 13.77. Time: 2.6s. ETA: 7.6s.
# Train batch 52/54. Loss: 13.55. Time: 2.4s. ETA: 4.9s.
# Train batch 53/54. Loss: 13.49. Time: 2.4s. ETA: 2.4s.
# Train batch 54/54. Loss: 14.69. Time: 2.4s. ETA: 0s.
# Validation batch 1/36. Time: 818ms. ETA: 28s.
# Validation batch 2/36. Time: 780ms. ETA: 27s.
# Train batch 14/54. Loss: 15.17. Time: 2.4s. ETA: 1m 39s.
# Train batch 15/54. Loss: 14.51. Time: 2.4s. ETA: 1m 35s.
# Train batch 16/54. Loss: 14.11. Time: 2.4s. ETA: 1m 32s.
# Train batch 17/54. Loss: 14.42. Time: 2.4s. ETA: 1m 29s.
# Train batch 18/54. Loss: 14.37. Time: 2.4s. ETA: 1m 26s.
# Train batch 19/54. Loss: 14.33. Time: 2.4s. ETA: 1m 23s.
# Train batch 20/54. Loss: 14.74. Time: 2.4s. ETA: 1m 21s.
# Train batch 21/54. Loss: 14.48. Time: 2.5s. ETA: 1m 20s.
# Train batch 22/54. Loss: 14.16. Time: 2.4s. ETA: 1m 17s.
# Train batch 23/54. Loss: 14.34. Time: 2.4s. ETA: 1m 14s.
# Train batch 24/54. Loss: 14.34. Time: 2.4s. ETA: 1m 11s.
# Train batch 25/54. Loss: 14.10. Time: 2.4s. ETA: 1m 10s.
# Train batch 26/54. Loss: 14.01. Time: 2.4s. ETA: 1m 7s.
# Train batch 27/54. Loss: 13.33. Time: 2.4s. ETA: 1m 5s.
# Train batch 28/54. Loss: 14.39. Time: 2.4s. ETA: 1m 2s.
# Train batch 29/54. Loss: 15.01. Time: 2.5s. ETA: 1m 1s.
# Train batch 30/54. Loss: 13.88. Time: 2.9s. ETA: 1m 2s.
# Train batch 31/54. Loss: 13.94. Time: 2.8s. ETA: 1m 2s.
# Train batch 32/54. Loss: 13.99. Time: 2.7s. ETA: 59s.
# Train batch 33/54. Loss: 14.60. Time: 2.8s. ETA: 57s.
# Train batch 34/54. Loss: 14.50. Time: 3.1s. ETA: 57s.
# Train batch 35/54. Loss: 14.05. Time: 3.2s. ETA: 57s.
# Train batch 36/54. Loss: 14.89. Time: 3.9s. ETA: 1m 0s.
# Train batch 37/54. Loss: 14.66. Time: 4.3s. ETA: 1m 3s.
# Train batch 38/54. Loss: 14.39. Time: 4.3s. ETA: 1m 3s.
# Train batch 39/54. Loss: 13.85. Time: 2.7s. ETA: 51s.
# Train batch 40/54. Loss: 13.76. Time: 2.9s. ETA: 45s.
# Train batch 41/54. Loss: 13.50. Time: 2.8s. ETA: 39s.
# Train batch 42/54. Loss: 13.87. Time: 2.6s. ETA: 34s.
# Train batch 43/54. Loss: 14.23. Time: 2.7s. ETA: 30s.
# Train batch 44/54. Loss: 13.78. Time: 2.6s. ETA: 27s.
# Train batch 45/54. Loss: 15.51. Time: 2.7s. ETA: 24s.
# Train batch 46/54. Loss: 13.72. Time: 2.7s. ETA: 21s.
# Train batch 47/54. Loss: 13.87. Time: 2.7s. ETA: 18s.
# Train batch 48/54. Loss: 13.49. Time: 2.7s. ETA: 16s.
# Train batch 49/54. Loss: 14.09. Time: 2.7s. ETA: 13s.
# Train batch 50/54. Loss: 13.52. Time: 2.6s. ETA: 10s.
# Train batch 51/54. Loss: 13.88. Time: 2.8s. ETA: 8.1s.
# Train batch 52/54. Loss: 14.44. Time: 3.0s. ETA: 5.7s.
# Train batch 53/54. Loss: 13.18. Time: 2.7s. ETA: 2.8s.
# Train batch 11/54. Loss: 13.89. Time: 2.6s. ETA: 1m 57s.
# Train batch 12/54. Loss: 15.06. Time: 2.7s. ETA: 1m 54s.
# Train batch 13/54. Loss: 14.04. Time: 2.6s. ETA: 1m 50s.
# Train batch 14/54. Loss: 14.05. Time: 2.7s. ETA: 1m 47s.
# Train batch 15/54. Loss: 13.65. Time: 2.7s. ETA: 1m 44s.
# Train batch 16/54. Loss: 13.54. Time: 2.7s. ETA: 1m 43s.
# Train batch 17/54. Loss: 15.01. Time: 2.7s. ETA: 1m 39s.
# Train batch 18/54. Loss: 14.66. Time: 2.8s. ETA: 1m 38s.
# Train batch 19/54. Loss: 13.88. Time: 2.6s. ETA: 1m 34s.
# Train batch 20/54. Loss: 14.34. Time: 2.9s. ETA: 1m 34s.
# Train batch 21/54. Loss: 14.34. Time: 3.2s. ETA: 1m 36s.
# Train batch 22/54. Loss: 14.02. Time: 2.9s. ETA: 1m 33s.
# Train batch 23/54. Loss: 13.95. Time: 2.8s. ETA: 1m 28s.
# Train batch 24/54. Loss: 13.25. Time: 2.8s. ETA: 1m 25s.
# Train batch 25/54. Loss: 13.56. Time: 2.9s. ETA: 1m 22s.
# Train batch 26/54. Loss: 13.96. Time: 2.9s. ETA: 1m 19s.
# Train batch 27/54. Loss: 15.11. Time: 2.8s. ETA: 1m 16s.
# Train batch 28/54. Loss: 14.39. Time: 2.7s. ETA: 1m 12s.
# Train batch 29/54. Loss: 14.18. Time: 2.8s. ETA: 1m 9s.
# Train batch 30/54. Loss: 14.13. Time: 2.8s. ETA: 1m 7s.
# Train batch 31/54. Loss: 14.14. Time: 2.7s. ETA: 1m 3s.
# Train batch 32/54. Loss: 13.86. Time: 2.7s. ETA: 1m 0s.
# Train batch 33/54. Loss: 13.76. Time: 2.9s. ETA: 58s.
# Train batch 34/54. Loss: 14.00. Time: 2.7s. ETA: 54s.
# Train batch 35/54. Loss: 13.90. Time: 2.8s. ETA: 52s.
# Train batch 36/54. Loss: 13.85. Time: 2.7s. ETA: 49s.
# Train batch 37/54. Loss: 13.38. Time: 2.8s. ETA: 47s.
# Train batch 38/54. Loss: 14.24. Time: 2.7s. ETA: 43s.
# Train batch 39/54. Loss: 13.56. Time: 2.7s. ETA: 40s.
# Train batch 40/54. Loss: 13.11. Time: 2.8s. ETA: 38s.
# Train batch 41/54. Loss: 14.30. Time: 2.7s. ETA: 35s.
# Train batch 42/54. Loss: 14.70. Time: 2.7s. ETA: 32s.
# Train batch 43/54. Loss: 13.69. Time: 2.7s. ETA: 29s.
# Train batch 44/54. Loss: 14.47. Time: 2.7s. ETA: 26s.
# Train batch 45/54. Loss: 14.61. Time: 2.7s. ETA: 24s.
# Train batch 46/54. Loss: 13.48. Time: 2.7s. ETA: 21s.
# Train batch 47/54. Loss: 13.78. Time: 2.6s. ETA: 18s.
# Train batch 48/54. Loss: 14.31. Time: 2.7s. ETA: 16s.
# Train batch 49/54. Loss: 13.04. Time: 2.6s. ETA: 13s.
# Train batch 50/54. Loss: 13.82. Time: 2.6s. ETA: 10s.
# Train batch 51/54. Loss: 13.82. Time: 2.5s. ETA: 7.8s.
# Train batch 52/54. Loss: 13.49. Time: 2.7s. ETA: 5.3s.
# Train batch 53/54. Loss: 14.41. Time: 2.7s. ETA: 2.7s.
# Train batch 54/54. Loss: 13.50. Time: 2.8s. ETA: 0s.
# Validation batch 1/36. Time: 964ms. ETA: 33s.
# Validation batch 2/36. Time: 867ms. ETA: 31s.
# Validation batch 3/36. Time: 936ms. ETA: 30s.
# Validation batch 4/36. Time: 927ms. ETA: 29s.
# Validation batch 5/36. Time: 1.0s. ETA: 29s.
# Validation batch 6/36. Time: 1.1s. ETA: 28s.
# Validation batch 7/36. Time: 1.0s. ETA: 28s.
# Validation batch 8/36. Time: 1.1s. ETA: 27s.
# Validation batch 9/36. Time: 1.1s. ETA: 26s.
# Validation batch 10/36. Time: 967ms. ETA: 25s.
# Validation batch 11/36. Time: 955ms. ETA: 24s.
# Validation batch 12/36. Time: 940ms. ETA: 23s.
# Validation batch 13/36. Time: 930ms. ETA: 22s.
# Validation batch 14/36. Time: 962ms. ETA: 21s.
# Validation batch 15/36. Time: 906ms. ETA: 20s.
# Validation batch 16/36. Time: 984ms. ETA: 19s.
# Validation batch 17/36. Time: 1.2s. ETA: 18s.
# Validation batch 18/36. Time: 1.1s. ETA: 17s.
# Validation batch 19/36. Time: 954ms. ETA: 16s.
# ...
# Train batch 43/54. Loss: 2.05. Time: 2.8s. ETA: 29s.
# Train batch 44/54. Loss: 2.13. Time: 2.6s. ETA: 26s.
# Train batch 45/54. Loss: 1.76. Time: 2.6s. ETA: 23s.
# Train batch 46/54. Loss: 2.03. Time: 2.6s. ETA: 20s.
# Train batch 47/54. Loss: 2.11. Time: 3.4s. ETA: 20s.
# Train batch 48/54. Loss: 2.42. Time: 2.9s. ETA: 17s.
# Train batch 49/54. Loss: 2.27. Time: 1h 5m. ETA: 2h 9m.
# Train batch 50/54. Loss: 2.10. Time: 17s. ETA: 1h 3m.
# Train batch 51/54. Loss: 1.76. Time: 6.2s. ETA: 28m.
# Train batch 52/54. Loss: 1.86. Time: 4.7s. ETA: 11m.
# Train batch 53/54. Loss: 1.90. Time: 4.5s. ETA: 3m 35s.
# Train batch 54/54. Loss: 2.02. Time: 3.6s. ETA: 0s.
# Validation batch 1/36. Time: 1.1s. ETA: 38s.
# Validation batch 2/36. Time: 1.0s. ETA: 35s.
# Validation batch 3/36. Time: 1.0s. ETA: 34s.
# Validation batch 4/36. Time: 977ms. ETA: 32s.
# Validation batch 5/36. Time: 982ms. ETA: 31s.
# Validation batch 6/36. Time: 1.1s. ETA: 30s.
# Validation batch 7/36. Time: 1.3s. ETA: 30s.
# Validation batch 8/36. Time: 1.2s. ETA: 30s.
# Validation batch 9/36. Time: 1.3s. ETA: 29s.
# Validation batch 10/36. Time: 1.3s. ETA: 29s.
# Validation batch 11/36. Time: 1.2s. ETA: 28s.
# Validation batch 12/36. Time: 1.2s. ETA: 27s.
# Validation batch 13/36. Time: 1.2s. ETA: 26s.
# Validation batch 14/36. Time: 1.3s. ETA: 25s.
# Validation batch 15/36. Time: 1.2s. ETA: 24s.
# Validation batch 16/36. Time: 1.2s. ETA: 23s.
# Validation batch 17/36. Time: 1.1s. ETA: 22s.
# Validation batch 18/36. Time: 1.2s. ETA: 21s.
# Validation batch 19/36. Time: 1.1s. ETA: 19s.
# Validation batch 20/36. Time: 1.3s. ETA: 18s.
# Validation batch 21/36. Time: 1.4s. ETA: 17s.
# Validation batch 22/36. Time: 1.2s. ETA: 16s.
# Validation batch 23/36. Time: 1.1s. ETA: 15s.
# Validation batch 24/36. Time: 1.2s. ETA: 14s.
# Validation batch 25/36. Time: 1.3s. ETA: 13s.
# Validation batch 26/36. Time: 1.3s. ETA: 11s.
# Validation batch 27/36. Time: 1.2s. ETA: 10s.
# Validation batch 28/36. Time: 1.2s. ETA: 9.5s.
# Validation batch 29/36. Time: 1.2s. ETA: 8.3s.
# Validation batch 30/36. Time: 1.1s. ETA: 7.1s.
# Validation batch 31/36. Time: 1.1s. ETA: 5.9s.
# Validation batch 32/36. Time: 1.0s. ETA: 4.7s.
# Validation batch 33/36. Time: 1.0s. ETA: 3.5s.
# Validation batch 34/36. Time: 1.0s. ETA: 2.3s.
# Validation batch 35/36. Time: 1.0s. ETA: 1.2s.
# Validation batch 36/36. Time: 994ms. ETA: 0s.
# Validation results: CER: 0.438, WA: 0.229.
# Epoch 176 complete in 1h 9m. T-loss is 2.03, V-loss is 8.40
# Epoch: 177
# Train batch 1/54. Loss: 1.99. Time: 3.2s. ETA: 2m 47s.
# Train batch 2/54. Loss: 2.09. Time: 3.2s. ETA: 2m 44s.
# Train batch 3/54. Loss: 2.11. Time: 3.1s. ETA: 2m 40s.
# Train batch 4/54. Loss: 2.25. Time: 3.1s. ETA: 2m 36s.
# Train batch 5/54. Loss: 1.99. Time: 3.2s. ETA: 2m 34s.
# Train batch 6/54. Loss: 1.99. Time: 3.3s. ETA: 2m 33s.
# Train batch 7/54. Loss: 2.21. Time: 3.3s. ETA: 2m 31s.
# Train batch 8/54. Loss: 2.01. Time: 3.2s. ETA: 2m 28s.
# Train batch 9/54. Loss: 1.77. Time: 3.3s. ETA: 2m 26s.
# Train batch 10/54. Loss: 2.08. Time: 3.2s. ETA: 2m 22s.
# Train batch 11/54. Loss: 1.95. Time: 3.3s. ETA: 2m 20s.
# Train batch 12/54. Loss: 2.13. Time: 3.4s. ETA: 2m 19s.
# Train batch 13/54. Loss: 2.17. Time: 3.4s. ETA: 2m 17s.
# Train batch 14/54. Loss: 2.10. Time: 3.3s. ETA: 2m 13s.
# Train batch 15/54. Loss: 2.13. Time: 3.2s. ETA: 2m 8s.
# Train batch 16/54. Loss: 1.97. Time: 3.2s. ETA: 2m 4s.
# Train batch 17/54. Loss: 1.70. Time: 3.4s. ETA: 2m 3s.
# Train batch 18/54. Loss: 1.90. Time: 3.5s. ETA: 2m 2s.
# Train batch 19/54. Loss: 2.22. Time: 3.2s. ETA: 1m 56s.
# Train batch 20/54. Loss: 2.01. Time: 3.3s. ETA: 1m 52s.
# Train batch 21/54. Loss: 2.07. Time: 3.2s. ETA: 1m 47s.
# Train batch 22/54. Loss: 2.20. Time: 3.3s. ETA: 1m 44s.
# Train batch 23/54. Loss: 2.47. Time: 3.2s. ETA: 1m 39s.
# Train batch 24/54. Loss: 2.02. Time: 3.2s. ETA: 1m 36s.
# Train batch 25/54. Loss: 1.94. Time: 3.3s. ETA: 1m 34s.
# Train batch 26/54. Loss: 2.24. Time: 3.3s. ETA: 1m 31s.
# Train batch 27/54. Loss: 2.01. Time: 3.2s. ETA: 1m 27s.
# Train batch 28/54. Loss: 1.90. Time: 3.4s. ETA: 1m 26s.
# Train batch 29/54. Loss: 1.77. Time: 3.2s. ETA: 1m 22s.
# Train batch 30/54. Loss: 1.99. Time: 3.3s. ETA: 1m 19s.
# Train batch 31/54. Loss: 1.76. Time: 3.2s. ETA: 1m 14s.
# Train batch 32/54. Loss: 2.08. Time: 3.3s. ETA: 1m 11s.
# Train batch 33/54. Loss: 1.64. Time: 3.3s. ETA: 1m 8s.
# Train batch 34/54. Loss: 2.08. Time: 3.2s. ETA: 1m 4s.
# Train batch 35/54. Loss: 1.85. Time: 3.5s. ETA: 1m 3s.
# Train batch 36/54. Loss: 1.87. Time: 3.2s. ETA: 59s.
# Train batch 37/54. Loss: 2.17. Time: 3.4s. ETA: 56s.
# Train batch 38/54. Loss: 2.24. Time: 3.5s. ETA: 54s.
# Train batch 39/54. Loss: 2.12. Time: 3.2s. ETA: 49s.
# Train batch 40/54. Loss: 2.24. Time: 3.3s. ETA: 46s.
# Train batch 41/54. Loss: 2.07. Time: 3.2s. ETA: 42s.
# Train batch 42/54. Loss: 2.09. Time: 3.3s. ETA: 39s.
# Train batch 43/54. Loss: 2.27. Time: 3.1s. ETA: 35s.
# Train batch 44/54. Loss: 2.12. Time: 3.2s. ETA: 32s.
# Train batch 45/54. Loss: 2.07. Time: 3.4s. ETA: 29s.
# Train batch 46/54. Loss: 1.79. Time: 3.2s. ETA: 25s.
# Train batch 47/54. Loss: 1.57. Time: 3.4s. ETA: 23s.
# Train batch 48/54. Loss: 2.24. Time: 3.4s. ETA: 19s.
# Train batch 49/54. Loss: 1.77. Time: 3.3s. ETA: 16s.
# Train batch 50/54. Loss: 2.04. Time: 3.3s. ETA: 13s.
# Train batch 51/54. Loss: 2.30. Time: 3.6s. ETA: 10s.
# Train batch 52/54. Loss: 2.16. Time: 3.2s. ETA: 6.7s.
# Train batch 53/54. Loss: 2.23. Time: 3.2s. ETA: 3.3s.
# Train batch 54/54. Loss: 2.10. Time: 3.3s. ETA: 0s.
# Validation batch 1/36. Time: 1.1s. ETA: 37s.
# Validation batch 2/36. Time: 1.1s. ETA: 36s.
# Validation batch 3/36. Time: 1.1s. ETA: 36s.
# Validation batch 4/36. Time: 1.1s. ETA: 35s.
# Validation batch 5/36. Time: 1.1s. ETA: 34s.
# Validation batch 6/36. Time: 1.2s. ETA: 33s.
# Validation batch 7/36. Time: 1.1s. ETA: 32s.
# Validation batch 8/36. Time: 1.2s. ETA: 31s.
# Validation batch 9/36. Time: 1.2s. ETA: 30s.
# Validation batch 10/36. Time: 1.1s. ETA: 29s.
# Validation batch 11/36. Time: 1.3s. ETA: 28s.
# Validation batch 12/36. Time: 1.1s. ETA: 27s.
# Validation batch 13/36. Time: 1.1s. ETA: 26s.
# Validation batch 14/36. Time: 1.1s. ETA: 25s.
# Validation batch 15/36. Time: 1.1s. ETA: 24s.
# Validation batch 16/36. Time: 1.1s. ETA: 22s.
# Validation batch 17/36. Time: 1.1s. ETA: 21s.
# Validation batch 18/36. Time: 1.1s. ETA: 20s.
# Validation batch 19/36. Time: 1.1s. ETA: 19s.
# Validation batch 20/36. Time: 1.2s. ETA: 18s.
# Validation batch 21/36. Time: 1.2s. ETA: 17s.
# Validation batch 22/36. Time: 1.1s. ETA: 15s.
# Validation batch 23/36. Time: 1.1s. ETA: 14s.
# Validation batch 24/36. Time: 1.1s. ETA: 13s.
# Validation batch 25/36. Time: 1.1s. ETA: 12s.
# Validation batch 26/36. Time: 1.1s. ETA: 11s.
# Validation batch 27/36. Time: 1.1s. ETA: 10s.
# Validation batch 28/36. Time: 1.0s. ETA: 9.0s.
# Validation batch 29/36. Time: 1.1s. ETA: 7.9s.
# Validation batch 30/36. Time: 1.1s. ETA: 6.8s.
# Validation batch 31/36. Time: 1.1s. ETA: 5.6s.
# Validation batch 32/36. Time: 1.1s. ETA: 4.5s.
# Validation batch 33/36. Time: 1.2s. ETA: 3.4s.
# Validation batch 34/36. Time: 1.1s. ETA: 2.3s.
# Validation batch 35/36. Time: 1.1s. ETA: 1.1s.
# Validation batch 36/36. Time: 1.1s. ETA: 0s.
# Validation results: CER: 0.437, WA: 0.233.
# Epoch 177 complete in 3m 38s. T-loss is 2.02, V-loss is 8.42
# Epoch: 178
# Train batch 1/54. Loss: 2.30. Time: 3.3s. ETA: 2m 57s.
# Train batch 2/54. Loss: 2.06. Time: 3.3s. ETA: 2m 52s.
# Train batch 3/54. Loss: 1.93. Time: 3.2s. ETA: 2m 45s.
# Train batch 4/54. Loss: 2.14. Time: 3.2s. ETA: 2m 41s.
# Train batch 5/54. Loss: 1.87. Time: 3.2s. ETA: 2m 36s.
# Train batch 6/54. Loss: 1.91. Time: 3.2s. ETA: 2m 33s.
# Train batch 7/54. Loss: 2.28. Time: 3.2s. ETA: 2m 29s.
# Train batch 8/54. Loss: 2.16. Time: 3.3s. ETA: 2m 28s.
# Train batch 9/54. Loss: 2.03. Time: 3.3s. ETA: 2m 25s.
# Train batch 10/54. Loss: 2.11. Time: 3.3s. ETA: 2m 23s.
# Train batch 11/54. Loss: 2.13. Time: 3.2s. ETA: 2m 19s.
# Train batch 12/54. Loss: 1.90. Time: 2.9s. ETA: 2m 10s.
# Train batch 13/54. Loss: 2.07. Time: 3.0s. ETA: 2m 5s.
# Train batch 14/54. Loss: 2.06. Time: 2.7s. ETA: 1m 57s.
# Train batch 15/54. Loss: 1.95. Time: 2.6s. ETA: 1m 49s.
# Train batch 16/54. Loss: 1.91. Time: 2.6s. ETA: 1m 42s.
# Train batch 17/54. Loss: 2.01. Time: 2.9s. ETA: 1m 43s.
# Train batch 18/54. Loss: 2.24. Time: 3.1s. ETA: 1m 45s.
# Train batch 19/54. Loss: 1.96. Time: 3.5s. ETA: 1m 50s.
# Train batch 20/54. Loss: 2.05. Time: 3.3s. ETA: 1m 49s.
# Train batch 21/54. Loss: 2.19. Time: 3.4s. ETA: 1m 47s.
# Train batch 22/54. Loss: 1.93. Time: 3.4s. ETA: 1m 45s.
# Train batch 23/54. Loss: 1.83. Time: 3.6s. ETA: 1m 46s.
# Train batch 24/54. Loss: 2.14. Time: 3.4s. ETA: 1m 43s.
# Train batch 25/54. Loss: 1.91. Time: 3.4s. ETA: 1m 38s.
# Train batch 26/54. Loss: 2.27. Time: 3.4s. ETA: 1m 34s.
# Train batch 27/54. Loss: 1.87. Time: 3.4s. ETA: 1m 31s.
# Train batch 28/54. Loss: 1.97. Time: 3.6s. ETA: 1m 30s.
# Train batch 29/54. Loss: 2.30. Time: 3.3s. ETA: 1m 25s.
# Train batch 30/54. Loss: 2.17. Time: 3.3s. ETA: 1m 20s.
# Train batch 31/54. Loss: 2.10. Time: 3.6s. ETA: 1m 19s.
# Train batch 32/54. Loss: 1.98. Time: 3.6s. ETA: 1m 17s.
# Train batch 33/54. Loss: 1.88. Time: 3.4s. ETA: 1m 12s.
# Train batch 34/54. Loss: 1.76. Time: 3.4s. ETA: 1m 9s.
# Train batch 35/54. Loss: 2.11. Time: 3.2s. ETA: 1m 3s.
# Train batch 36/54. Loss: 2.09. Time: 3.1s. ETA: 58s.
# Train batch 37/54. Loss: 1.89. Time: 3.2s. ETA: 54s.
# Train batch 38/54. Loss: 1.90. Time: 3.3s. ETA: 51s.
# Train batch 39/54. Loss: 2.34. Time: 3.2s. ETA: 48s.
# Train batch 40/54. Loss: 2.01. Time: 3.1s. ETA: 44s.
# Train batch 41/54. Loss: 2.04. Time: 3.2s. ETA: 41s.
# Train batch 42/54. Loss: 1.95. Time: 3.3s. ETA: 38s.
# Train batch 43/54. Loss: 1.89. Time: 3.4s. ETA: 36s.
# Train batch 44/54. Loss: 1.64. Time: 3.3s. ETA: 33s.
# Train batch 45/54. Loss: 2.02. Time: 3.2s. ETA: 29s.
# Train batch 46/54. Loss: 2.17. Time: 3.2s. ETA: 25s.
# Train batch 47/54. Loss: 2.28. Time: 3.1s. ETA: 22s.
# Train batch 48/54. Loss: 2.14. Time: 3.1s. ETA: 18s.
# Train batch 49/54. Loss: 2.44. Time: 3.2s. ETA: 15s.
# Train batch 50/54. Loss: 2.03. Time: 3.1s. ETA: 12s.
# Train batch 51/54. Loss: 1.97. Time: 3.3s. ETA: 9.6s.
# Train batch 52/54. Loss: 1.84. Time: 3.6s. ETA: 6.7s.
# Train batch 53/54. Loss: 1.82. Time: 3.3s. ETA: 3.3s.
# Train batch 54/54. Loss: 2.31. Time: 3.3s. ETA: 0s.
# Validation batch 1/36. Time: 1.1s. ETA: 39s.
# Validation batch 2/36. Time: 1.1s. ETA: 37s.
# Validation batch 3/36. Time: 1.0s. ETA: 35s.
# Validation batch 4/36. Time: 991ms. ETA: 33s.
# Validation batch 5/36. Time: 1.1s. ETA: 33s.
# Validation batch 6/36. Time: 1.1s. ETA: 31s.
# Validation batch 7/36. Time: 998ms. ETA: 30s.
# Validation batch 8/36. Time: 1.0s. ETA: 29s.
# Validation batch 9/36. Time: 969ms. ETA: 28s.
# Validation batch 10/36. Time: 974ms. ETA: 26s.
# Validation batch 11/36. Time: 965ms. ETA: 25s.
# Validation batch 12/36. Time: 977ms. ETA: 24s.
# Validation batch 13/36. Time: 1.0s. ETA: 23s.
# Validation batch 14/36. Time: 970ms. ETA: 22s.
# Validation batch 15/36. Time: 981ms. ETA: 21s.
# Validation batch 16/36. Time: 959ms. ETA: 20s.
# Validation batch 17/36. Time: 975ms. ETA: 19s.
# Validation batch 18/36. Time: 988ms. ETA: 18s.
# Validation batch 19/36. Time: 961ms. ETA: 17s.
# Validation batch 20/36. Time: 981ms. ETA: 16s.
# Validation batch 21/36. Time: 1.1s. ETA: 15s.
# Validation batch 22/36. Time: 992ms. ETA: 14s.
# Validation batch 23/36. Time: 958ms. ETA: 13s.
# Validation batch 24/36. Time: 983ms. ETA: 12s.
# Validation batch 25/36. Time: 972ms. ETA: 11s.
# Validation batch 26/36. Time: 1.0s. ETA: 10s.
# Validation batch 27/36. Time: 1.0s. ETA: 9.1s.
# Validation batch 28/36. Time: 971ms. ETA: 8.0s.
# Validation batch 29/36. Time: 982ms. ETA: 7.0s.
# Validation batch 30/36. Time: 1.0s. ETA: 6.0s.
# Validation batch 31/36. Time: 982ms. ETA: 5.0s.
# Validation batch 32/36. Time: 988ms. ETA: 4.0s.
# Validation batch 33/36. Time: 996ms. ETA: 3.0s.
# Validation batch 34/36. Time: 972ms. ETA: 2.0s.
# Validation batch 35/36. Time: 961ms. ETA: 1.0s.
# Validation batch 36/36. Time: 985ms. ETA: 0s.
# Validation results: CER: 0.438, WA: 0.233.
# Epoch 178 complete in 3m 31s. T-loss is 2.02, V-loss is 8.43
# Epoch: 179
# Train batch 1/54. Loss: 2.16. Time: 3.1s. ETA: 2m 44s.
# Train batch 2/54. Loss: 2.13. Time: 3.2s. ETA: 2m 43s.
# Train batch 3/54. Loss: 2.03. Time: 3.3s. ETA: 2m 44s.
# Train batch 4/54. Loss: 1.99. Time: 3.2s. ETA: 2m 39s.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-5ceac874299f> in <module>
#       1 run_training(model, train_imgs, train_lbls, valid_imgs, valid_lbls,
# ----> 2             batch_size=256, train_pipeline=train_pipeline, valid_pipeline=valid_pipeline)
#
# <ipython-input-3-21c33d791476> in run_training(model, train_imgs, train_labels, valid_imgs, valid_labels, batch_size, train_pipeline, valid_pipeline)
#     102         print('Epoch: {}'.format(epoch))
#     103
# --> 104         tloss = train(model, train_imgs, train_labels, batch_size, transform_pipeline=train_pipeline)
#     105         vloss, cer, wa = validate(model, valid_imgs, valid_labels, batch_size, transform_pipeline=valid_pipeline)
#     106         model.save()
#
# <ipython-input-3-21c33d791476> in train(model, imgs, labels, batch_size, transform_pipeline)
#      45         batch_imgs = np.array([transform_pipeline.transform(imgs[j]) for j in batch_ids])
#      46         batch_lbls = np.array([labels[j] for j in batch_ids])
# ---> 47         loss = model.trainBatch(batch_imgs, batch_lbls)
#      48         sum_loss += loss * len(batch_lbls)
#      49         t1 = time.perf_counter()
#
# d:\Programming\bujo_poc\proof-of-concepts\src\htr_model.py in trainBatch(self, imgs, texts)
#     201                     self.tf_learning_rate_ : rate,
#     202                     self.tf_is_train_: True}
# --> 203         (_, lossVal) = self.tf_session_.run(evalList, feedDict)
#     204         self.trained_samples_ += batch_size
#     205         return lossVal
#
# C:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     948     try:
#     949       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 950                          run_metadata_ptr)
#     951       if run_metadata:
#     952         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# C:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1171     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1172       results = self._do_run(handle, final_targets, final_fetches,
# -> 1173                              feed_dict_tensor, options, run_metadata)
#    1174     else:
#    1175       results = []
#
# C:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1348     if handle is None:
#    1349       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1350                            run_metadata)
#    1351     else:
#    1352       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# C:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1354   def _do_call(self, fn, *args):
#    1355     try:
# -> 1356       return fn(*args)
#    1357     except errors.OpError as e:
#    1358       message = compat.as_text(e.message)
#
# C:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1339       self._extend_graph()
#    1340       return self._call_tf_sessionrun(
# -> 1341           options, feed_dict, fetch_list, target_list, run_metadata)
#    1342
#    1343     def _prun_fn(handle, feed_dict, fetch_list):
#
# C:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1427     return tf_session.TF_SessionRun_wrapper(
#    1428         self._session, options, feed_dict, fetch_list, target_list,
# -> 1429         run_metadata)
#    1430
#    1431   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
tloss, tcer, twa = validate(model, train_imgs, train_lbls, 256, valid_pipeline)
# Out:
# Validation batch 1/54. Time: 1.3s. ETA: 1m 6s.
# Validation batch 2/54. Time: 1.2s. ETA: 1m 4s.
# Validation batch 3/54. Time: 1.3s. ETA: 1m 4s.
# Validation batch 4/54. Time: 1.3s. ETA: 1m 3s.
# Validation batch 5/54. Time: 1.2s. ETA: 1m 1s.
# Validation batch 6/54. Time: 1.3s. ETA: 1m 0s.
# Validation batch 7/54. Time: 1.3s. ETA: 59s.
# Validation batch 8/54. Time: 1.3s. ETA: 58s.
# Validation batch 9/54. Time: 1.3s. ETA: 57s.
# Validation batch 10/54. Time: 1.2s. ETA: 55s.
# Validation batch 11/54. Time: 1.2s. ETA: 54s.
# Validation batch 12/54. Time: 1.5s. ETA: 53s.
# Validation batch 13/54. Time: 1.3s. ETA: 52s.
# Validation batch 14/54. Time: 1.2s. ETA: 51s.
# Validation batch 15/54. Time: 1.3s. ETA: 49s.
# Validation batch 16/54. Time: 1.3s. ETA: 48s.
# Validation batch 17/54. Time: 1.3s. ETA: 47s.
# Validation batch 18/54. Time: 1.2s. ETA: 45s.
# Validation batch 19/54. Time: 1.3s. ETA: 44s.
# Validation batch 20/54. Time: 1.3s. ETA: 43s.
# Validation batch 21/54. Time: 1.3s. ETA: 42s.
# Validation batch 22/54. Time: 1.4s. ETA: 41s.
# Validation batch 23/54. Time: 1.4s. ETA: 39s.
# Validation batch 24/54. Time: 1.4s. ETA: 38s.
# Validation batch 25/54. Time: 1.3s. ETA: 37s.
# Validation batch 26/54. Time: 1.3s. ETA: 36s.
# Validation batch 27/54. Time: 1.5s. ETA: 35s.
# Validation batch 28/54. Time: 1.4s. ETA: 33s.
# Validation batch 29/54. Time: 1.4s. ETA: 32s.
# Validation batch 30/54. Time: 1.6s. ETA: 31s.
# Validation batch 31/54. Time: 1.2s. ETA: 30s.
# Validation batch 32/54. Time: 1.4s. ETA: 28s.
# Validation batch 33/54. Time: 1.3s. ETA: 27s.
# Validation batch 34/54. Time: 1.2s. ETA: 26s.
# Validation batch 35/54. Time: 1.3s. ETA: 24s.
# Validation batch 36/54. Time: 1.3s. ETA: 23s.
# Validation batch 37/54. Time: 1.3s. ETA: 22s.
# Validation batch 38/54. Time: 1.3s. ETA: 20s.
# Validation batch 39/54. Time: 1.4s. ETA: 19s.
# Validation batch 40/54. Time: 1.4s. ETA: 18s.
# Validation batch 41/54. Time: 1.3s. ETA: 17s.
# Validation batch 42/54. Time: 1.2s. ETA: 15s.
# Validation batch 43/54. Time: 1.2s. ETA: 14s.
# Validation batch 44/54. Time: 1.2s. ETA: 13s.
# Validation batch 45/54. Time: 1.3s. ETA: 11s.
# Validation batch 46/54. Time: 1.3s. ETA: 10s.
# Validation batch 47/54. Time: 1.5s. ETA: 9.2s.
# Validation batch 48/54. Time: 1.4s. ETA: 7.9s.
# Validation batch 49/54. Time: 1.3s. ETA: 6.6s.
# Validation batch 50/54. Time: 1.3s. ETA: 5.2s.
# Validation batch 51/54. Time: 1.3s. ETA: 3.9s.
# Validation batch 52/54. Time: 1.3s. ETA: 2.6s.
# Validation batch 53/54. Time: 1.3s. ETA: 1.3s.
# Validation batch 54/54. Time: 1.3s. ETA: 0s.
# Validation results: CER: 0.105, WA: 0.681.

# %%
vloss, vcer, vwa = validate(model, valid_imgs, valid_lbls, 256, valid_pipeline)
# Out:
# Validation batch 1/36. Time: 1.3s. ETA: 45s.
# Validation batch 2/36. Time: 1.2s. ETA: 43s.
# Validation batch 3/36. Time: 1.3s. ETA: 42s.
# Validation batch 4/36. Time: 1.3s. ETA: 41s.
# Validation batch 5/36. Time: 1.2s. ETA: 39s.
# Validation batch 6/36. Time: 1.3s. ETA: 38s.
# Validation batch 7/36. Time: 1.3s. ETA: 37s.
# Validation batch 8/36. Time: 1.2s. ETA: 35s.
# Validation batch 9/36. Time: 1.3s. ETA: 34s.
# Validation batch 10/36. Time: 1.4s. ETA: 33s.
# Validation batch 11/36. Time: 1.4s. ETA: 32s.
# Validation batch 12/36. Time: 1.4s. ETA: 31s.
# Validation batch 13/36. Time: 1.6s. ETA: 30s.
# Validation batch 14/36. Time: 1.4s. ETA: 29s.
# Validation batch 15/36. Time: 1.3s. ETA: 27s.
# Validation batch 16/36. Time: 1.4s. ETA: 26s.
# Validation batch 17/36. Time: 1.3s. ETA: 25s.
# Validation batch 18/36. Time: 1.2s. ETA: 23s.
# Validation batch 19/36. Time: 1.3s. ETA: 22s.
# Validation batch 20/36. Time: 1.4s. ETA: 21s.
# Validation batch 21/36. Time: 1.2s. ETA: 19s.
# Validation batch 22/36. Time: 1.2s. ETA: 18s.
# Validation batch 23/36. Time: 1.2s. ETA: 17s.
# Validation batch 24/36. Time: 1.3s. ETA: 15s.
# Validation batch 25/36. Time: 1.4s. ETA: 14s.
# Validation batch 26/36. Time: 1.3s. ETA: 13s.
# Validation batch 27/36. Time: 1.3s. ETA: 11s.
# Validation batch 28/36. Time: 1.3s. ETA: 10s.
# Validation batch 29/36. Time: 1.4s. ETA: 9.2s.
# Validation batch 30/36. Time: 1.3s. ETA: 7.9s.
# Validation batch 31/36. Time: 1.3s. ETA: 6.6s.
# Validation batch 32/36. Time: 1.3s. ETA: 5.3s.
# Validation batch 33/36. Time: 1.3s. ETA: 3.9s.
# Validation batch 34/36. Time: 1.4s. ETA: 2.6s.
# Validation batch 35/36. Time: 1.3s. ETA: 1.3s.
# Validation batch 36/36. Time: 1.2s. ETA: 0s.
# Validation results: CER: 0.437, WA: 0.233.

# %%
(tcer, vcer), (twa, vwa)
# Out:
# ((0.10549381491036582, 0.43740463561723464),
#  (0.6814236111111112, 0.23274739583333334))
