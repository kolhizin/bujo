# %%
import test_config as cfg
import numpy as np
import matplotlib.pyplot as plt
import cv2
import json
import os, os.path
import pickle

# %%
print(cfg.sample_path)
# Out:
# D:/Data/bujo_sample

# %%
tst_fname = os.path.join(cfg.sample_path, os.listdir(cfg.sample_path)[0])
tst_fname
# Out:
# 'D:/Data/bujo_sample\\20190309_125032.jpg'

# %%
src = cv2.imread(tst_fname)

# %%
plt.imshow(src)

# %%
plt.imshow(src[300:600, 300:600])
